# %% [markdown]
# Key Performance Indicators (KPI's)

# %%
total_revenue = df['Total'].sum()
total_orders = df['OrderID'].nunique()
avg_order_value = df['Total'].mean()
total_units = df['Units'].sum()

print(f"📈 Total Revenue: ₹{total_revenue:,.0f}")
print(f"🧾 Total Orders: {total_orders}")
print(f"💰 Average Order Value: ₹{avg_order_value:,.2f}")
print(f"📦 Total Units Sold: {total_units}")
# Out:
# 📈 Total Revenue: ₹319,789
# 🧾 Total Orders: 100
# 💰 Average Order Value: ₹3,197.89
# 📦 Total Units Sold: 563

# %% [markdown]
# # 📊 Sales Analysis Report (Jan–June 2023)
# This report explores sales trends, top products, regional performance, and salesperson behavior using Python and Pandas.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("sales_data.csv") 
df.head()
# Out:
#    OrderID        Date Region SalesPerson  Product  Units  UnitCost  Total
# 0     1001  2023-06-01  South     Charlie   Laptop      3       578   1734
# 1     1002  2023-01-27  South         Bob  Monitor      9       208   1872
# 2     1003  2023-06-21   East     Charlie  Monitor      6       704   4224
# 3     1004  2023-06-12  South       Fiona  Printer      2       175    350
# 4     1005  2023-05-15  North     Charlie    Phone      5       162    810

# %% [markdown]
# monthly sales trend

# %%
# Group by product and sum total sales
top_products = df.groupby('Product')['Total'].sum().sort_values(ascending=False).head(5)

# Plot
plt.figure(figsize=(8, 5))
top_products.plot(kind='bar', color='teal')
plt.title("Top 5 Products by Total Sales")
plt.xlabel("Product")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# 💰 Average Order Value per Month

# %% [markdown]
# df['Date'] = pd.to_datetime(df['Date'])
#
# avg_order_value = df.groupby(df['Date'].dt.to_period('M'))['Total'].mean()
# avg_order_value.index = avg_order_value.index.to_timestamp()
# plt.figure(figsize=(10,5))
# plt.plot(avg_order_value.index,avg_order_value.values,marker='o',color='darkorange')
# plt.title('Average Order by Month:')
# plt.xlabel('Month')
# plt.ylabel('Average Order Value')
# plt.grid(True)
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# Total Sales By Region

# %%
# Group sales by region
sales_by_region = df.groupby('Region')['Total'].sum().sort_values(ascending=False)

# Plot
plt.figure(figsize=(8, 5))
sales_by_region.plot(kind='bar', color='seagreen')
plt.title("Total Sales by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# Top performing Salespeople

# %%
order_count=df.groupby('SalesPerson')['OrderID'].count().sort_values(ascending=False).head(5)
sales_amount=df.groupby('SalesPerson')['Total'].sum().sort_values(ascending=False).head(5)
print('Top 5 Salespeople by Order Handled:')
print(order_count)
print('Top 5 Salespeople by Sales Amount')
print(sales_amount)
# Out:
# Top 5 Salespeople by Order Handled:
# SalesPerson
# Charlie    29
# Fiona      21
# Alice      15
# Bob        13
# Diana      13
# Name: OrderID, dtype: int64
# Top 5 Salespeople by Sales Amount
# SalesPerson
# Charlie    87828
# Fiona      63444
# Alice      54066
# Diana      45695
# Bob        40421
# Name: Total, dtype: int64

# %% [markdown]
# Sales person Performence (chart)

# %%
plt.figure(figsize=(8,4))
order_count.plot(kind='bar',color='skyblue')
plt.title('\n Top 5 Salespeople by Order Handled\n:')
plt.xlabel('SalesPerson')
plt.ylabel('Number of Orders')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# Top 5 Sales people by Sales amount

# %%
plt.figure(figsize=(8,4))
sales_amount.plot(kind='bar',color='orange')
plt.title('Top 5 Sales people by Sales amount')
plt.xlabel('SalesPerson')
plt.ylabel('Amount')
plt.grid(axis='y')
plt.tight_layout()
plt.show()
